# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'ieee','no-latex', 'bright'])

# %%
#helper functions
def get_error(pred, target):
    # differences = np.abs(target-pred)
    differences = target-pred
    return 100*(differences/target)

def preprocess_data(data):
    # done after applying hilbert transform
    shifted_ut = np.zeros(data.shape)
    for i in range(data.shape[0]):
        for j in range(data.shape[2]):
            # a_scan = data[i,:,j]
            # peak = np.argmax(a_scan[:250])
            # shifted_a_scan = a_scan[peak::]
            # shifted_ut[i,0:(data.shape[1]-peak),j] = shifted_a_scan
            # shifted_ut[i,:,j] = shifted_ut[i,:,j]/np.max(shifted_ut[i,:,j])
            shifted_ut[i,:,j] = data[i,:,j]/np.nanmax(data[i,:,j])
    return shifted_ut

# %%
data=np.load('C:/Users/Shaun McKnight/OneDrive - University of Strathclyde/SEARCH NDE/Composites/Exp Data/Spirit Cell/New scans/ID018/ID018_hilbert_raster.npy')
print(data.shape)

data=preprocess_data(data)
# Out:
# (271, 2000, 305)
# C:\Users\SHAUNM~1\AppData\Local\Temp/ipykernel_32788/1108164811.py:17: RuntimeWarning: invalid value encountered in true_divide
#   shifted_ut[i,:,j] = data[i,:,j]/np.nanmax(data[i,:,j])

# %%
plt.figure()
plt.imshow(data[190,:,130:130+64], aspect='auto')
plt.show()

plt.figure()
plt.imshow(data[:,150,:])
plt.show()

plt.figure()
plt.imshow(data[:,150,130:170])
plt.show()

plt.figure()
plt.plot(data[:,150,150])
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times

# %%
test=np.copy(data[:,150,150])

# %%
plt.plot(test)

threshold=150
prediction=np.zeros(np.shape(test))
errors=np.zeros(np.shape(test))
for i in range(0, prediction.size-1):
    current_pred=test[i]
    target=test[i+1]
    error=get_error(current_pred, target)
    errors[i+1]=error
    if error>threshold:
        prediction[i+1]=1
        test[i+1]=current_pred

# %%
plt.figure()
plt.plot(errors)
plt.plot(test)
plt.show()

plt.figure()
plt.plot(test)
plt.show()

plt.figure()
plt.plot(prediction)
plt.show()

# %% [markdown]
# # test model

# %%
import numpy as np
import itertools
import time
import datetime
import math
from pathlib import Path
import os

import torchvision.transforms as transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchvision.utils import make_grid
import torch.nn.functional as F
import torch
from torchinfo import summary
from torch.utils.data import Dataset
import torch.distributions as dist

import classifier

# %%
class CleanDataset(Dataset):
    def __init__(self, data, transforms_=None):
        self.transform = transforms.Compose(transforms_)
        
        self.id007=data
            
        print('~~~~ Synthetic dataloader INFO ~~~~~')
        print('Number points train ~ ', 'Max/Min ', np.amax(self.id007), np.amin(self.id007))
        #length 500 time series
              
    def __getitem__(self, index):       
        base_data=self.id007[index:index+65]
        
        data = base_data[:64]
        label = base_data[64]   
        
        return torch.from_numpy(np.copy(data)).unsqueeze(0), torch.from_numpy(np.copy(label)).unsqueeze(0)
        #At least one stride in the given numpy array is negative, and tensors with negative strides are not currently supported. (You can probably work around this by making a copy of your array  with array.copy().) 

    def __len__(self):
        return self.id007.size-65

# %%
def validation(
    dataloader,
    Tensor,
    Net,
):
    targets = []
    predictions = []
    priors = []
    # TRAINING
    prev_time = time.time()
    Net.eval()
    with torch.no_grad():
        for i, batch in enumerate(dataloader):
            data, labels = batch
            data.type(Tensor)
            labels.type(Tensor)
            
            if torch.cuda.is_available():
                data = data.cuda()
                labels = labels.cuda()

            # forward + backward + optimize
            outputs = Net(data)
            
            [targets.append(labels[i].cpu().numpy()) for i in range(
                len(labels.squeeze().cpu().numpy()))]
            
            [predictions.append(outputs[i].cpu().numpy()) for i in range(
                len(outputs.squeeze().cpu().numpy()))]
            
            # [print(data[i][-1].shape) for i in range(
            #     len(outputs.squeeze().cpu().numpy()))]
            [priors.append(data[i][-1][-1].cpu().numpy()) for i in range(
                len(outputs.squeeze().cpu().numpy()))]
            
#             plt.figure()
#             plt.plot(data[i].cpu().numpy())
#             plt.plot(test[i:64])

    errors_percent=get_error(np.squeeze(predictions), np.squeeze(targets))
    errors_priors=get_error(np.squeeze(priors), np.squeeze(targets))
    print('Finished Validation')
    return errors_percent, errors_priors, targets, predictions

# %%
def validation2(
    test_data,
    Tensor,
    Net,
    threshold=0.99,
    plot=None
):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
    predictions = np.zeros(test_data.shape)
    segmented = np.zeros(test_data.shape)
    errors = np.zeros(test_data.shape)
    
    test_mapped=np.copy(test_data)
    prediction_mapped=[]
    
    prev_time = time.time()
    Net.eval()
    
    threshold=np.full(test_mapped.shape[0], threshold)
    threshold=torch.Tensor(threshold).to(device).unsqueeze(1)


    nan_indices = np.argwhere(np.isnan(test_mapped))
    if nan_indices.size > 0:
        print("NaN values are located at:")
        for index in nan_indices:
            print(index)
    else:
        print("Test data does not contain NaN values.")
        
    with torch.no_grad():
        for i in range(0,test_mapped.shape[1]-65):
            batch=torch.Tensor(np.expand_dims(test_mapped[:,i:i+64],1))
            targets=np.squeeze(test_mapped[:,i+64])
                        
            batch=batch.to(device)
            
            out_means, out_std = Net(batch)
            
            dists=dist.Normal(out_means, out_std)
            out_means=out_means.squeeze().cpu().numpy()
            
#             cdf_values=[]
            
#             for j in range(0, targets.size):
#                 norm_dist=dist.Normal(out_means[j], out_std[j])
#                 # x=(norm_dist.cdf(torch.Tensor(targets).to(device).squeeze()[j]).cpu().numpy())
#                 x=(norm_dist.icdf(torch.Tensor(targets).to(device).squeeze()[j]).cpu().numpy())
#                 cdf_values.append(x)
#             cdf_values=np.array(cdf_values)  

            threshold_values=dists.icdf(threshold).squeeze().cpu().numpy()
            
            # try:
            #     # cdf_value=dists.cdf(torch.Tensor(targets).to(device).unsqueeze(0))
            # except:
            #     labels=['targets', 'means', 'stds', 'batch']
            #     for i,tensor in enumerate([torch.Tensor(targets).to(device).squeeze(), torch.Tensor(out_means).to(device).squeeze(), out_std, batch]):
            #         if torch.isnan(tensor).any().item():
            #             print(f'Nans found in in {labels[i]}')
            #             print(tensor)

            if np.isnan(test_mapped[:,i+64]).any():
                print(f'Nans found in updated values')
                print(test_mapped[:,i+64])
                
            if plot:
                # if i>150:
                idx=0
                threshold_value=dists.icdf(threshold)[idx].cpu().numpy()
                plt.figure(figsize=(10,5))
                plt.plot(batch[idx,:,:].cpu().numpy().squeeze().squeeze(), label='Signal')
                plt.scatter(64, targets[idx], label='GT', marker='o')
                # plt.errorbar(64, out_means[idx], yerr=threshold_value, capsize=10,label='Thresholded prediction', marker='x')
                plt.scatter(64, out_means[idx],label='Mean prediction', marker='x')
                plt.scatter(64, threshold_value, label='Threshold', marker='_')
                # plt.scatter(64, out_means[idx], label='Prediction', marker='x')
                plt.legend()
                plt.xlabel('Samples')
                plt.ylabel('Amplitude')
                plt.show()
                print('Target    : ',out_means[idx])
                print('Prediction: ',targets[idx])
                print('Threshold : ',threshold_value)
                
            # mask=cdf_value>(threshold)
            # mask=torch.Tensor(cdf_values).to(device)>(threshold)
            mask=targets>threshold_values
            print('test')
            print(targets-threshold_values)
            print(mask.shape)
            # print(cdf_values.max(), cdf_values.min())
            # mask=mask[:, 0].cpu().numpy()

            # test_mapped[:,i+64]=np.putmask(test_mapped[:,i+64], mask, out_means[mask])
            test_mapped[:,i+64][mask]=out_means[mask] # check these are working, strange broadcasting behavour
            segmented[:,i+64]=mask
            predictions[:,i+64]=out_means
            errors[:,i+64]=get_error(out_means, targets)
            
            # print(targets[idx],prediction[idx],threshold_value)
    
#     plt.figure()
#     plt.imshow(test_data)
#     plt.show()
    
#     plt.figure()
#     plt.imshow(test_mapped)
#     plt.show()
    
#     plt.figure()
#     plt.imshow(errors)
#     plt.show()

#     plt.figure()
#     plt.imshow(segmented)
#     plt.show()


    print('Finished Validation, inference time: ', time.time() - prev_time)
    return errors, segmented, predictions, test_mapped

# %%
def validationv2(
    test_data,
    Tensor,
    Net,
    threshold=0.99,
    plot=None
):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
    predictions = np.zeros(test_data.shape)
    segmented = np.zeros(test_data.shape)
    errors = np.zeros(test_data.shape)
    
    test_mapped=np.copy(test_data)
    prediction_mapped=[]
    
    prev_time = time.time()
    Net.eval()
    
    threshold=np.full(test_mapped.shape[0], threshold)
    threshold=torch.Tensor(threshold).to(device).unsqueeze(1)


    nan_indices = np.argwhere(np.isnan(test_mapped))
    if nan_indices.size > 0:
        print("NaN values are located at:")
        for index in nan_indices:
            print(index)
    else:
        print("Test data does not contain NaN values.")
        
    with torch.no_grad():
        for i in range(0,test_mapped.shape[1]-65):
            batch=torch.Tensor(np.expand_dims(test_mapped[:,i:i+64],1))
            targets=np.squeeze(test_mapped[:,i+64])
            targets=torch.Tensor(targets).cpu().numpy()          
            batch=batch.to(device)
            
            out_means, out_std = Net(batch)
            dists=dist.Normal(out_means, out_std)
            out_means=out_means.squeeze().cpu().numpy()

         
            threshold_values=dists.icdf(threshold).squeeze().cpu().numpy()
             
            mask=np.copy(targets)>np.copy(threshold_values)
            

            test_mapped[:,i+64][mask]=out_means[mask] # check these are working, strange broadcasting behavour
            # segmented[:,i+64]=mask
            predictions[:,i+64]=out_means
            errors[:,i+64]=get_error(out_means, targets)
            
            if plot:
                # if i>150:
                idx=0
                
                print(mask[idx])
                print('Target    : ',targets[idx])
                print('Prediction: ',out_means[idx])
                print('Threshold : ',threshold_values[idx])
                if mask[idx]==1:
                    print('Threshold exceeded!!!', mask[idx])
                plt.figure(figsize=(10,5))
                plt.plot(batch[idx,:,:].cpu().numpy().squeeze().squeeze(), label='Signal')
                plt.scatter(64, targets[idx], label='GT', marker='o')
                plt.scatter(64, out_means[idx], label='Mean prediction', marker='x')
                plt.scatter(64, threshold_values[idx], label='Threshold', marker='_')
                plt.legend()
                plt.xlabel('Samples')
                plt.ylabel('Amplitude')
                plt.show()
                
        segmented[test_data!=test_mapped]=1

            # print(targets[idx],prediction[idx],threshold_value)
    
#     plt.figure()
#     plt.imshow(test_data)
#     plt.show()
    
#     plt.figure()
#     plt.imshow(test_mapped)
#     plt.show()
    
#     plt.figure()
#     plt.imshow(errors)
#     plt.show()

#     plt.figure()
#     plt.imshow(segmented)
#     plt.show()


    print('Finished Validation, inference time: ', time.time() - prev_time)
    return errors, segmented, predictions, test_mapped

# %%
def validation3(
    test_data,
    Tensor,
    Net,
    threshold=6
):
    predictions = np.zeros(test_data.shape)
    segmented = np.zeros(test_data.shape)
    errors = np.zeros(test_data.shape)
    
    test_mapped=np.copy(test_data)
    prediction_mapped=[]
    
    prev_time = time.time()
    Net.eval()
    
    with torch.no_grad():
        for j in range(0,test_mapped.shape[0]):
            for i in range(100,test_mapped.shape[1]-65):
                # print(test_mapped[j,i:i+64]==test_data[j,i:i+64])
                input_data=test_mapped[j,i:i+64]
                target=test_mapped[j,i+64]

                input_data = torch.from_numpy(input_data).unsqueeze(0).unsqueeze(0)
                
                if torch.cuda.is_available():
                    input_data = input_data.cuda()
                    

                prediction = Net(input_data)
                prediction = prediction.cpu().numpy()
                
                error = get_error(prediction, target)
            
                if error>threshold:
                    predictions[j,i+64]=1
                    test_mapped[j,i+64]=prediction
                else:
                    predictions[j,i+64]=0

                errors[j,i+64]=error
                
                # print(error)
                # plt.figure()
                # plt.plot(np.squeeze(np.squeeze(input_data.cpu().numpy())))
                # plt.plot(test_mapped[j,i:i+64])
                # plt.scatter(64, prediction)
                # plt.scatter(64, target, marker='x')
                # plt.ylim(1,2)
                # plt.xlim(50)
                # plt.show()

    
    plt.figure()
    plt.imshow(test_data)
    plt.show()
    
    plt.figure()
    plt.imshow(test_mapped)
    plt.show()
    
    plt.figure()
    plt.imshow(errors)
    plt.show()

    plt.figure()
    plt.imshow(predictions)
    plt.show()


    print('Finished Validation, inference time: ', time.time() - prev_time)
    return errors, segmented, predictions, test_mapped

test=data[:,150,130:170]
print(test.shape)
errors, segmented, predictions, mapped_data = validation3(
        np.swapaxes(test+1,0,1),#[20:23,:], #need d axes at the end
        Tensor=Tensor,
        Net=top_model,
        threshold=8.69#7.53
    )
# Out:
# (271, 40)
# Finished Validation, inference time:  9.891191720962524

# %%
#data loader
test_dataloader = DataLoader(
        CleanDataset(test, transforms_ = True),
        batch_size=2,
        shuffle=False,
        # num_workers=1,
)
# Out:
# ~~~~ Synthetic dataloader INFO ~~~~~
# Number points train ~  Max/Min  nan nan

# %%
# model_path = 'C:/GIT/Self-supervised-volumetric-detection/saved_models/exp_4/best_model_epoch_702_model.pt' #209 is model w/o adjustment up
model_path = 'C:/GIT/Self-supervised-volumetric-detection/saved_models/dist/epoch_69_model.pth'
top_model = classifier.CNN()
top_model.load_state_dict(torch.load(model_path))

# top_model = torch.load(model_path)
# print(top_model)

cuda = True if torch.cuda.is_available() else False
Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

if cuda:
    top_model = top_model.to('cuda')
    print('Cuda')
# Out:
# Cuda

# %%
errors_percent, errors_priors, targets, prediction = validation(
        dataloader=test_dataloader,
        Tensor=Tensor,
        Net=top_model,
    )

# %%
test=data[:269,150,130:170]
if np.isnan(test).any():
    print(f'Nans found in data')
plt.imshow(test, aspect='auto')
plt.show()


print(test.shape)
errors, segmented, predictions, mapped_data = validation2(
        np.swapaxes(test+1,0,1),#[20:23,:], #need d axes at the end
        Tensor=Tensor,
        Net=top_model,
        threshold=0.99,#8.69#7.53
        plot=True
    )

# %%
plt.plot(data[10,:,10])
plt.show()

test=data[20:250,0:800:10,130:]
test=np.pad(test,((64,0),(0,0),(0,0)),'edge')
print(test.shape)
plt.figure()
plt.imshow(np.amax(data[:,200:,:],1))
plt.clim(0,1)
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(np.amax(test[:,20:,:],1))
plt.clim(0,1)
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(test[:,:,23])
plt.show()

plt.figure()
plt.plot(test[0,0:600,5])
plt.show()
# Out:
# (294, 80, 175)

# %%
#for volume
# test=data[:,0:600:10,130:170]
# test=test[140:,:,21:23]
test=test[:,:,:]

# %%
segmented_volume=np.zeros(test.shape)
errors_total=np.zeros(test.shape)
print(test.shape)

# plt.imshow(np.amax(test[:,:,:], axis=1),aspect='auto')
# plt.show()

plt.imshow(test[:,:,0])

plt.figure()
plt.plot(test[:,32,0])
# plt.plot(test[140:,32,0])
plt.show()

start_time=time.time()

for i in range(0,test.shape[1]): #13-16
    print(i)
    # test_slice=test[:,i,:]
    test_slice=test[:,i,:]
    errors, segmented, predictions, mapped_data = validationv2(
            np.swapaxes(test_slice+1,0,1),#[20:23,:], #need d axes at the end
            Tensor=Tensor,
            Net=top_model,
            threshold=0.9999999,
            plot=True
    )
    
    # if i==32:
    #         errors, segmented, predictions, mapped_data = validationv2(
    #         np.swapaxes(test_slice+1,0,1),#[20:23,:], #need d axes at the end
    #         Tensor=Tensor,
    #         Net=top_model,
    #         threshold=0.999,
    #         plot=True
    # )
    # else:
    #         errors, segmented, predictions, mapped_data = validationv2(
    #         np.swapaxes(test_slice+1,0,1),#[20:23,:], #need d axes at the end
    #         Tensor=Tensor,
    #         Net=top_model,
    #         threshold=0.999,
    #         # threshold=0.9999999,
    #         # plot=True
    # )
    # print(np.median(errors),'%')
    # print(test_slice.shape)
    # print(segmented_volume[:,i,:].shape, segmented.shape)
    segmented_volume[:,i,:]=np.swapaxes(segmented, 0,1)
    errors_total[:,i,:]=np.swapaxes(errors, 0,1)
    print(f'{round(100*(i/segmented_volume.shape[1]), 2)}% complete')
print('FINISHED')
print('Complete time: ', time.time() - start_time)

# %%
# backward
test=data[20:250,0:800:10,130:]
test=np.pad(test,((0,64),(0,0),(0,0)),'edge')
test=np.flip(test, axis=0)

plt.figure()
plt.imshow(np.amax(test[:,20:,:],1))
plt.clim(0,1)
plt.colorbar()
plt.show()

segmented_volume_flipped=np.zeros(test.shape)
errors_total=np.zeros(test.shape)

start_time=time.time()

for i in range(0,test.shape[1]): #13-16
    print(i)
    # test_slice=test[:,i,:]
    test_slice=test[:,i,:]
    errors, segmented, predictions, mapped_data = validationv2(
            np.swapaxes(test_slice+1,0,1),#[20:23,:], #need d axes at the end
            Tensor=Tensor,
            Net=top_model,
            threshold=0.9999999,
            # plot=True
    )
    segmented_volume_flipped[:,i,:]=np.swapaxes(segmented, 0,1)
    errors_total[:,i,:]=np.swapaxes(errors, 0,1)
    print(f'{round(100*(i/segmented_volume_flipped.shape[1]), 2)}% complete')
print('FINISHED')
print('Complete time: ', time.time() - start_time)
# Out:
# 0
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.7487378120422363
# 0.0% complete
# 1
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.452664613723755
# 1.25% complete
# 2
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.4145994186401367
# 2.5% complete
# 3
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.4198763370513916
# 3.75% complete
# 4
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.364121913909912
# 5.0% complete
# 5
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.3605337142944336
# 6.25% complete
# 6
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.3923394680023193
# 7.5% complete
# 7
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.373685836791992
# 8.75% complete
# 8
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.4237022399902344
# 10.0% complete
# 9
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.4100334644317627
# 11.25% complete
# 10
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.4076220989227295
# 12.5% complete
# 11
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.542717933654785
# 13.75% complete
# 12
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.6528677940368652
# 15.0% complete
# 13
# Test data does not contain NaN values.
# Finished Validation, inference time:  2.8090438842773438
# 16.25% complete
# 14
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.010209321975708
# 17.5% complete
# 15
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.225229024887085
# 18.75% complete
# 16
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2230188846588135
# 20.0% complete
# 17
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2343618869781494
# 21.25% complete
# 18
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2273752689361572
# 22.5% complete
# 19
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2319397926330566
# 23.75% complete
# 20
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2550528049468994
# 25.0% complete
# 21
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.266876697540283
# 26.25% complete
# 22
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2469937801361084
# 27.5% complete
# 23
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2075164318084717
# 28.75% complete
# 24
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2356200218200684
# 30.0% complete
# 25
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2278242111206055
# 31.25% complete
# 26
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2699596881866455
# 32.5% complete
# 27
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2843446731567383
# 33.75% complete
# 28
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.6678826808929443
# 35.0% complete
# 29
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.556436061859131
# 36.25% complete
# 30
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5499489307403564
# 37.5% complete
# 31
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.561061382293701
# 38.75% complete
# 32
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.573002338409424
# 40.0% complete
# 33
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.7207491397857666
# 41.25% complete
# 34
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.565962553024292
# 42.5% complete
# 35
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2075493335723877
# 43.75% complete
# 36
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2390527725219727
# 45.0% complete
# 37
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.167503595352173
# 46.25% complete
# 38
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.1489171981811523
# 47.5% complete
# 39
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0858805179595947
# 48.75% complete
# 40
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.110562562942505
# 50.0% complete
# 41
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0930681228637695
# 51.25% complete
# 42
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0750088691711426
# 52.5% complete
# 43
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0952486991882324
# 53.75% complete
# 44
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0907745361328125
# 55.0% complete
# 45
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0643699169158936
# 56.25% complete
# 46
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.038661241531372
# 57.5% complete
# 47
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0299232006073
# 58.75% complete
# 48
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.036054849624634
# 60.0% complete
# 49
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.022843837738037
# 61.25% complete
# 50
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0219576358795166
# 62.5% complete
# 51
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0279948711395264
# 63.75% complete
# 52
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.123772144317627
# 65.0% complete
# 53
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2263882160186768
# 66.25% complete
# 54
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.0428965091705322
# 67.5% complete
# 55
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.028265953063965
# 68.75% complete
# 56
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.134108066558838
# 70.0% complete
# 57
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.2803237438201904
# 71.25% complete
# 58
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.435771942138672
# 72.5% complete
# 59
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.408320903778076
# 73.75% complete
# 60
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.405407428741455
# 75.0% complete
# 61
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.3991332054138184
# 76.25% complete
# 62
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.406259298324585
# 77.5% complete
# 63
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.498680353164673
# 78.75% complete
# 64
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.6317708492279053
# 80.0% complete
# 65
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5508790016174316
# 81.25% complete
# 66
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5585241317749023
# 82.5% complete
# 67
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.560281276702881
# 83.75% complete
# 68
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.554995059967041
# 85.0% complete
# 69
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5600552558898926
# 86.25% complete
# 70
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.550568103790283
# 87.5% complete
# 71
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5556445121765137
# 88.75% complete
# 72
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.552096128463745
# 90.0% complete
# 73
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.559354066848755
# 91.25% complete
# 74
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5568723678588867
# 92.5% complete
# 75
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.573915481567383
# 93.75% complete
# 76
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.544782876968384
# 95.0% complete
# 77
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.594088315963745
# 96.25% complete
# 78
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5686774253845215
# 97.5% complete
# 79
# Test data does not contain NaN values.
# Finished Validation, inference time:  3.5760297775268555
# 98.75% complete
# FINISHED
# Complete time:  254.22603249549866

# %%
print(test.shape)
print(segmented_volume.shape)

plt.figure()
plt.imshow(test[:,35,:],aspect='auto')
plt.colorbar()

plt.figure()
plt.imshow(segmented_volume[:,35,:],aspect='auto')
plt.colorbar()

plt.figure()
plt.imshow(np.amax(segmented_volume[:,:,:], axis=1),aspect='auto')
plt.colorbar()

# plt.figure()
# plt.imshow(np.amax(test[:,30:,:], axis=1),aspect='auto')
# plt.colorbar()

# plt.figure()
# plt.imshow(np.amax(segmented_volume[:,20:,:], axis=1),aspect='auto')
# plt.colorbar()

# plt.figure()
# plt.plot(segmented_volume[:,32,0])

# plt.figure()
# plt.plot(test[:,32,:], label='data')
# plt.plot(segmented_volume[:,32,:], label='volume')
# plt.legend()
# Out:
# (294, 80, 175)
# (294, 80, 175)

# %%
print(test.shape)
print(segmented_volume.shape)

plt.figure()
plt.imshow(test[:,:,145],aspect='auto')
plt.colorbar()

plt.figure()
plt.imshow(segmented_volume[:,:,145],aspect='auto')
plt.colorbar()

print(test.shape)
print(segmented_volume.shape)

plt.figure()
plt.imshow(test[:,:,17],aspect='auto')
plt.colorbar()

plt.figure()
plt.imshow(segmented_volume[:,:,17],aspect='auto')
plt.colorbar()
# Out:
# (294, 80, 175)
# (294, 80, 175)
# (294, 80, 175)
# (294, 80, 175)

# %%
both_ways=np.copy(segmented_volume[64:,:,:])

both_ways=np.add(np.flip(segmented_volume_flipped[64:,:,:], axis=0), both_ways)
# both_ways[both_ways<2]=0
# both_ways[both_ways>0]=1

plt.figure()
plt.imshow(np.amax(segmented_volume[:,:,:], axis=1),aspect='auto')
plt.colorbar()
plt.savefig('forward.png')
plt.show()


plt.figure()
plt.imshow(np.amax(segmented_volume_flipped[:,:,:], axis=1),aspect='auto')
plt.colorbar()
plt.savefig('backward.png')
plt.show()

plt.figure()
plt.imshow(np.amax(both_ways, axis=1),aspect='auto')
plt.colorbar()
plt.savefig('forward_and_backward.png')
plt.show()

# %%
# np.save('results/segmented_volume',segmented_volume)
np.save('results/segmented_volume_forward_and_back',both_ways)
# np.save('errors',errors_total)
# np.save('test_data',test)

# %%
plt.figure()
plt.title('Errors hist')
plt.hist(errors_total.flatten(), bins=1000)
plt.xlim(0,15)
plt.show()

# %%
print(data.shape)
plt.figure()
plt.imshow(data[170:190,150,155:170], aspect='auto')

plt.figure()
plt.plot(data[185,:600,150])
plt.figure()

plt.plot(data[185,0:600:10,150])
# plt.plot(data[190,:,24])
# plt.plot(data[182,:,24])
# Out:
# (271, 2000, 305)

# %%
print(np.nanmin(mapped_data), np.nanmax(mapped_data), np.mean(mapped_data))
print(np.amin(errors), np.amax(errors), np.mean(errors))
print(errors.shape)

nan_mask = np.isnan(mapped_data)

# Create a plot showing NaN locations as a heatmap
plt.imshow(nan_mask, cmap='viridis', interpolation='nearest')

plt.figure()
plt.plot(errors[20,])

plt.figure()
plt.imshow(errors[:,200:])
plt.colorbar()
# Out:
# 1.070129231700755 2.0 1.7885372324887465
# -72.30303607754493 21.392554865843188 -0.3869918240519434
# (175, 294)

# %%
print(segmented.shape)
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.imshow(np.swapaxes(test+1,0,1), aspect='auto')

plt.subplot(2, 2, 2)
plt.imshow(np.clip(mapped_data, 1,2), aspect='auto')

plt.subplot(2, 2, 3)
plt.imshow(np.clip(errors, 1,10), aspect='auto')
plt.colorbar()

plt.subplot(2, 2, 4)
plt.imshow(segmented, aspect='auto')
plt.colorbar()

plt.figure()
plt.imshow(abs(np.swapaxes(test+1,0,1)-np.clip(mapped_data, 1,5)), aspect='auto')
plt.colorbar()
# Out:
# (175, 294)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SHAUNM~1\AppData\Local\Temp/ipykernel_32788/1246200764.py in <module>
#       3
#       4 plt.subplot(2, 2, 1)
# ----> 5 plt.imshow(np.swapaxes(test+1,0,1), aspect='auto')
#       6
#       7 plt.subplot(2, 2, 2)
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2638         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2639         resample=None, url=None, data=None, **kwargs):
# -> 2640     __ret = gca().imshow(
#    2641         X, cmap=cmap, norm=norm, aspect=aspect,
#    2642         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5440                               **kwargs)
#    5441
# -> 5442         im.set_data(X)
#    5443         im.set_alpha(alpha)
#    5444         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\torch_phd\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     713         if not (self._A.ndim == 2
#     714                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 715             raise TypeError("Invalid shape {} for image data"
#     716                             .format(self._A.shape))
#     717
#
# TypeError: Invalid shape (60, 294, 175) for image data

# %%
plot = np.swapaxes(test+1,0,1)
print(plot.shape)
plt.figure()
plt.imshow(plot[:,150:200], aspect='auto')

plt.figure()
plt.plot(test[])
# Out:
#   File "C:\Users\SHAUNM~1\AppData\Local\Temp/ipykernel_32788/2010781894.py", line 7
#     plt.plot(test[])
#                   ^
# SyntaxError: invalid syntax
